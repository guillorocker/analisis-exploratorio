# %%
import pandas as pd

# %%
import ydata_profiling

# %%
from pathlib import Path

# %%
dir = Path.cwd()
file = dir/'file/sh_ipc_aperturas.xls'
print(file)
# Out:
# /home/guillorocker/Desktop/python/jupyternotebook/file/sh_ipc_aperturas.xls

# %%
m_df = pd.ExcelFile(file)

# %%
nrows = m_df.book.sheet_by_name('Índices aperturas').nrows
print(nrows)
# Out:
# 302

# %%
df1 = m_df.parse(2, skiprows=5,skipfooter=nrows-52, parse_dates=True).dropna(axis=0, how='all')
df1.describe()
# Out:
#        2016-12-01  2017-01-01  2017-02-01  2017-03-01  2017-04-01  2017-05-01  \
# count        45.0   45.000000   45.000000   45.000000   45.000000   45.000000
# mean        100.0  101.488471  104.121222  106.534627  109.303024  110.746153
# std           0.0    1.562521    3.506579    5.288426    7.640399    7.361471
# min         100.0   97.304400   96.490900   99.978900   99.354000  101.131900
# 25%         100.0  100.601700  102.989300  104.181100  106.129600  107.596500
# 50%         100.0  101.474500  103.808500  105.681900  107.939400  109.321500
# 75%         100.0  102.273000  105.287500  107.135800  109.581200  111.639000
# max         100.0  104.661300  117.597500  132.893600  149.213700  149.844600
#
#        2017-06-01  2017-07-01  2017-08-01  2017-09-01  ...   2022-04-01  \
# count   45.000000   45.000000   45.000000   45.000000  ...    45.000000
# mean   112.196024  114.121998  116.111647  118.473589  ...   689.600707
# ...

# %%
print(df1.columns)
# Out:
# Index([       'Región GBA', 2016-12-01 00:00:00, 2017-01-01 00:00:00,
#        2017-02-01 00:00:00, 2017-03-01 00:00:00, 2017-04-01 00:00:00,
#        2017-05-01 00:00:00, 2017-06-01 00:00:00, 2017-07-01 00:00:00,
#        2017-08-01 00:00:00, 2017-09-01 00:00:00, 2017-10-01 00:00:00,
#        2017-11-01 00:00:00, 2017-12-01 00:00:00, 2018-01-01 00:00:00,
#        2018-02-01 00:00:00, 2018-03-01 00:00:00, 2018-04-01 00:00:00,
#        2018-05-01 00:00:00, 2018-06-01 00:00:00, 2018-07-01 00:00:00,
#        2018-08-01 00:00:00, 2018-09-01 00:00:00, 2018-10-01 00:00:00,
#        2018-11-01 00:00:00, 2018-12-01 00:00:00, 2019-01-01 00:00:00,
#        2019-02-01 00:00:00, 2019-03-01 00:00:00, 2019-04-01 00:00:00,
#        2019-05-01 00:00:00, 2019-06-01 00:00:00, 2019-07-01 00:00:00,
#        2019-08-01 00:00:00, 2019-09-01 00:00:00, 2019-10-01 00:00:00,
#        2019-11-01 00:00:00, 2019-12-01 00:00:00, 2020-01-01 00:00:00,
# ...

# %%
region = df1.columns[0]
df1['region'] = region

# %%
print(df1)
# Out:
#                                            Región GBA  2016-12-01 00:00:00  \
# 1                                       Nivel general                100.0
# 2                  Alimentos y bebidas no alcohólicas                100.0
# 3                                           Alimentos                100.0
# 4                                      Pan y cereales                100.0
# 5                                  Carnes y derivados                100.0
# 6                   Leche, productos lácteos y huevos                100.0
# 7                           Aceites, grasas y manteca                100.0
# 8                                              Frutas                100.0
# 9                    Verduras, tubérculos y legumbres                100.0
# 10         Azúcar, dulces, chocolate, golosinas, etc.                100.0
# 11                             Bebidas no alcohólicas                100.0
# ...
