# %%
import pandas as pd

# %%
import ydata_profiling

# %%
from pathlib import Path

# %%
dir = Path.cwd()
file = dir/'file/sh_ipc_aperturas.xls'
print(file)
# Out:
# /home/guillorocker/Desktop/python/jupyternotebook/file/sh_ipc_aperturas.xls

# %%
m_df = pd.ExcelFile(file)

# %%
nrows = m_df.book.sheet_by_index(2).nrows
print(nrows)
# Out:
# 302

# %%
df1 = m_df.parse(0, skiprows=5,skipfooter=nrows-52, parse_dates=True).dropna(axis=0, how='all')
df1.describe()
# Out:
#        2017-01-01  2017-02-01  2017-03-01  2017-04-01  2017-05-01  2017-06-01  \
# count   45.000000   45.000000   45.000000   45.000000   45.000000   45.000000
# mean     1.500000    2.593333    2.291111    2.517778    1.348889    1.300000
# std      1.562486    3.228523    2.502891    2.446360    1.118364    0.925154
# min     -2.700000   -2.700000   -2.600000   -2.900000   -2.200000   -0.200000
# 25%      0.600000    0.700000    1.200000    1.200000    0.800000    0.700000
# 50%      1.500000    1.900000    1.900000    2.100000    1.300000    1.300000
# 75%      2.300000    3.300000    2.600000    2.800000    1.900000    1.900000
# max      4.700000   17.600000   13.000000   12.300000    4.800000    3.700000
#
#        2017-07-01  2017-08-01  2017-09-01  2017-10-01  ...  2022-04-01  \
# count   45.000000   45.000000   45.000000   45.000000  ...   45.000000
# mean     1.740000    1.733333    2.057778    1.484444  ...    5.706667
# ...

# %%
print(df1)
# Out:
#                                            Región GBA  2017-01-01 00:00:00  \
# 2                                       Nivel general                  1.3
# 3                  Alimentos y bebidas no alcohólicas                  1.3
# 4                                           Alimentos                  1.3
# 5                                      Pan y cereales                  1.5
# 6                                  Carnes y derivados                 -1.1
# 7                   Leche, productos lácteos y huevos                  2.2
# 8                           Aceites, grasas y manteca                  1.7
# 9                                              Frutas                  3.6
# 10                   Verduras, tubérculos y legumbres                  4.7
# 11         Azúcar, dulces, chocolate, golosinas, etc,                  1.9
# 12                             Bebidas no alcohólicas                  1.5
# ...
